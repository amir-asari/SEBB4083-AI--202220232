# %% [markdown]
# <a href="https://colab.research.google.com/github/amir-asari/SEBB4083-AI--202220232/blob/main/SEBB4083_LinearRegressionGradientDescentAnimation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# Generate some sample data with noise
np.random.seed(42)
x = np.array([2, 8, 11, 5, 3, 10, 13, 12, 9, 6])
y = np.array([1.56, 3.25, 2.87, 2.11, 1.76, 3.01, 3.68, 3.48, 2.92, 2.39])

# Define the gradient descent function
def gradient_descent(x, y, lr=0.01, epochs=300):
    # Initialize parameters
    w1 = 3
    w0 = 3
    
    # Create a figure and axis for the plot
    plt.xlim([0.0, 14.0])
    plt.ylim([0.0, 4.0])
    fig, ax = plt.subplots()
    ax.scatter(x, y)
    line, = ax.plot(x, m*x+b, color='red')
    
    # Define the animation function to update the line
    def update(i):
        nonlocal w1, w0
        # Calculate the gradients
        dw1 = (-2/len(x)) * np.sum(x * (y - (w1*x+w0)))
        dw0 = (-2/len(x)) * np.sum(y - (w1*x+w0))
        # Update the parameters
        w1 -= lr * dw1
        w0 -= lr * dw0
        # Update the line
        plt.xlim([0.0, 14.0])
        plt.ylim([0.0, 4.0])
        line.set_ydata(w1*x+w0)
        ax.set_title(f'Epoch: {i+1}')
        return line,
    
    # Create the animation
    ani = animation.FuncAnimation(fig, update, frames=epochs, interval=100, blit=True)
    
    # Return the final parameters
    return w1, w0, ani

# Run the gradient descent function
w1, w0, ani = gradient_descent(x, y)

# Show the final plot and animation
plt.show()
ani.save('linear_regression.gif', writer='pillow', fps=10)
