# %% [markdown]
# <a href="https://colab.research.google.com/github/amir-asari/SEBB4083-AI--202220232/blob/main/SEBB4083_VGG16_transferlearning2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## (Section 1)Transfer learning using VGG16 pretrained model
#
# There are 2 approaches in performing transfer learning
#
# 1. Feature Extraction (or Fixed Feature Extractor)
#
# In this approach, the pre-trained model (the Base Model or Backbone) is treated as a powerful, static feature processor.
#
# *   Mechanism: The weights of the entire pre-trained model are frozen (made non-trainable). The model is used solely to generate high-quality feature embeddings (numerical representations) from the new, raw input data.
# *   Training: Only a simple, small new classification layer (or output head) is added on top of the frozen base. This new head is then trained from scratch using the new dataset.
# *    Advantage: This method is fast and computationally cheap because only the small top layer is being trained. It is ideal when the new dataset is very small or when the new task is very similar to the original pre-training task.
#
#
# 2. Fine-Tuning (Full or Partial)
#
# Fine-Tuning involves strategically adjusting the weights of the pre-trained model to make its features more relevant to the new, specific task. This is the dominant approach for utilizing large Foundational Models.
#
# * Mechanism: Instead of freezing the entire Base Model, we unfreeze some or all of the original layers.
#
# * Training: The model is trained using a very low learning rate on the new, specific task data. This allows the internal weights of the pre-trained layers to be slightly adjusted or "fine-tuned."
#
# * Partial Fine-Tuning: Only the layers closest to the output (the higher-order feature layers) are unfrozen, as these are the layers that encode the task-specific information.
#
# * Advantage: This technique leads to the highest performance because it customizes the generic, learned features to the subtle characteristics of the new dataset. It is ideal when the new dataset is large enough to support additional training without causing the entire model to overfit.

# %% [markdown]
# ### Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil

import tensorflow as tf
from tensorflow.keras.layers import Rescaling
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

from sklearn.model_selection import train_test_split

# !pip install zipfile36
from zipfile36 import ZipFile
# Out:
# Requirement already satisfied: zipfile36 in /usr/local/lib/python3.12/dist-packages (0.1.3)

# %% [markdown]
# ###Data preprocessing
#
#
#
# ####Download data from gdrive link

# %%
! gdown 1spMPriOaaLHwLeTtL583aoDwJBVqnrhj
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1spMPriOaaLHwLeTtL583aoDwJBVqnrhj
# From (redirected): https://drive.google.com/uc?id=1spMPriOaaLHwLeTtL583aoDwJBVqnrhj&confirm=t&uuid=cd20a6d9-ef82-4d29-b1b3-e4896c46b5dc
# To: /content/dronedataset.zip
# 100% 1.57G/1.57G [00:28<00:00, 55.8MB/s]

# %% [markdown]
# ####Unzip the download file

# %%
with ZipFile('/content/dronedataset.zip','r') as zipObj:
  zipObj.extractall()

# %% [markdown]
# ####Load data using Keras utility
#
# Next, load these images off disk using the helpful tf.keras.utils.image_dataset_from_directory utility. This will take you from a directory of images on disk to a tf.data.Dataset in just a couple lines of code.

# %% [markdown]
# Create a dataset
#
# Define some parameters for the ImageDataGenerator:

# %%
batch_size = 50 # Of course here, we are using mini-batch gradient descent
img_height = 224
img_width = 224

# %% [markdown]
# Data splitting, into 70% training data and 30% testing data. Once splitted, all data will saved in folder called training_data and testing_data

# %%
# Define the path to your dataset directory
dataset_dir = '/content/dronedataset'

# Define the path to the directory where you want to create the train and test folders
output_dir = '/content/output'

# Define the percentage of data to be used for testing
test_split = 0.3

# Get the list of subfolders in the dataset directory
subfolders = [subfolder for subfolder in os.listdir(dataset_dir) if os.path.isdir(os.path.join(dataset_dir, subfolder))]

print(subfolders)

# Define the train and test folder paths
train_dir = os.path.join(output_dir, 'train')
test_dir = os.path.join(output_dir, 'test')

# Delete train and test folders if they already exist
if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
if os.path.exists(test_dir):
    shutil.rmtree(test_dir)

# Create the train and test folders in the output directory
os.makedirs(train_dir)
os.makedirs(test_dir)

# Iterate over each subfolder and split the images into train and test sets
for subfolder in subfolders:
    subfolder_path = os.path.join(dataset_dir, subfolder)
    images = os.listdir(subfolder_path)
    train_images, test_images = train_test_split(images, test_size=test_split, random_state=42)

    # Create the subfolders inside train and test directories
    train_subfolder_dir = os.path.join(train_dir, subfolder)
    test_subfolder_dir = os.path.join(test_dir, subfolder)
    os.makedirs(train_subfolder_dir)
    os.makedirs(test_subfolder_dir)

    # Move the train images to the train folder
    for image in train_images:
        src = os.path.join(subfolder_path, image)
        dst = os.path.join(train_dir, subfolder, image)
        print(src)
        print(dst)
        shutil.copyfile(src, dst)

    # Move the test images to the test folder
    for image in test_images:
        src = os.path.join(subfolder_path, image)
        dst = os.path.join(test_dir, subfolder, image)
        shutil.copyfile(src, dst)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/dronedataset/No_Fire/resized_test_nofire_frame2247.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2247.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5219.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5219.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame348.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame348.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8635.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8635.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2001.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2001.jpg
# /content/dronedataset/No_Fire/resized_frame16707.jpg
# /content/output/train/No_Fire/resized_frame16707.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame159.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame159.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2382.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2382.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1433.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1433.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1681.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1681.jpg
# /content/dronedataset/No_Fire/resized_frame17077.jpg
# /content/output/train/No_Fire/resized_frame17077.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9449.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9449.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4912.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4912.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10851.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10851.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7154.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7154.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4472.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4472.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3532.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3532.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8425.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8425.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame138.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame138.jpg
# /content/dronedataset/No_Fire/resized_frame17111.jpg
# /content/output/train/No_Fire/resized_frame17111.jpg
# /content/dronedataset/No_Fire/resized_frame16779.jpg
# /content/output/train/No_Fire/resized_frame16779.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1059.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1059.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1400.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1400.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9996.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9996.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame373.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame373.jpg
# /content/dronedataset/No_Fire/resized_frame4340.jpg
# /content/output/train/No_Fire/resized_frame4340.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10753.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10753.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6652.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6652.jpg
# /content/dronedataset/No_Fire/resized_frame4316.jpg
# /content/output/train/No_Fire/resized_frame4316.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3847.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3847.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10714.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10714.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame497.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame497.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7121.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7121.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2195.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2195.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3232.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3232.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3478.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3478.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame237.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame237.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7896.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7896.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10892.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10892.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5582.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5582.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5826.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5826.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4128.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4128.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4910.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4910.jpg
# /content/dronedataset/No_Fire/resized_frame16625.jpg
# /content/output/train/No_Fire/resized_frame16625.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5455.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5455.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2318.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2318.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1862.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1862.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2702.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2702.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6263.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6263.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2967.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2967.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8194.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8194.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10483.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10483.jpg
# /content/dronedataset/No_Fire/resized_frame16713.jpg
# /content/output/train/No_Fire/resized_frame16713.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3560.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3560.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame485.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame485.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6002.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6002.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3812.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3812.jpg
# /content/dronedataset/No_Fire/resized_frame17240.jpg
# /content/output/train/No_Fire/resized_frame17240.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9499.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9499.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7567.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7567.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7120.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7120.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1179.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1179.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10662.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10662.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5464.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5464.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame783.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame783.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1970.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1970.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4191.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4191.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1839.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1839.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4542.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4542.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8160.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8160.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2489.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2489.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8300.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8300.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1809.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1809.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3896.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3896.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2515.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2515.jpg
# /content/dronedataset/No_Fire/resized_frame17020.jpg
# /content/output/train/No_Fire/resized_frame17020.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9173.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9173.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11551.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11551.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame316.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame316.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10026.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10026.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2939.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2939.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11351.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11351.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7185.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7185.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6216.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6216.jpg
# /content/dronedataset/No_Fire/resized_frame4314.jpg
# /content/output/train/No_Fire/resized_frame4314.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10708.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10708.jpg
# /content/dronedataset/No_Fire/resized_frame6727.jpg
# /content/output/train/No_Fire/resized_frame6727.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2245.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2245.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3304.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3304.jpg
# /content/dronedataset/No_Fire/resized_frame4263.jpg
# /content/output/train/No_Fire/resized_frame4263.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8104.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8104.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7543.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7543.jpg
# /content/dronedataset/No_Fire/resized_frame4275.jpg
# /content/output/train/No_Fire/resized_frame4275.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6094.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6094.jpg
# /content/dronedataset/No_Fire/resized_frame6720.jpg
# /content/output/train/No_Fire/resized_frame6720.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1594.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1594.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10715.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10715.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4911.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4911.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9954.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9954.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9564.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9564.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6001.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6001.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3543.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3543.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1056.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1056.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5486.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5486.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5272.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5272.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5497.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5497.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7073.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7073.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1665.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1665.jpg
# /content/dronedataset/No_Fire/resized_frame3522.jpg
# /content/output/train/No_Fire/resized_frame3522.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1226.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1226.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame618.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame618.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5543.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5543.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3315.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3315.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4053.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4053.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2353.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2353.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7368.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7368.jpg
# /content/dronedataset/No_Fire/resized_frame11690.jpg
# /content/output/train/No_Fire/resized_frame11690.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame466.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame466.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6856.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6856.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2113.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2113.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4041.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4041.jpg
# /content/dronedataset/No_Fire/resized_frame16957.jpg
# /content/output/train/No_Fire/resized_frame16957.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame963.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame963.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1388.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1388.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8148.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8148.jpg
# /content/dronedataset/No_Fire/resized_frame4280.jpg
# /content/output/train/No_Fire/resized_frame4280.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10738.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10738.jpg
# /content/dronedataset/No_Fire/resized_frame3699.jpg
# /content/output/train/No_Fire/resized_frame3699.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2156.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2156.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9828.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9828.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5754.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5754.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7063.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7063.jpg
# /content/dronedataset/No_Fire/resized_frame3515.jpg
# /content/output/train/No_Fire/resized_frame3515.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7307.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7307.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1637.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1637.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3202.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3202.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1131.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1131.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9393.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9393.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7845.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7845.jpg
# /content/dronedataset/No_Fire/resized_frame3302.jpg
# /content/output/train/No_Fire/resized_frame3302.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4534.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4534.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6537.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6537.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4576.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4576.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9207.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9207.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7932.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7932.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11812.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11812.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame893.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame893.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2803.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2803.jpg
# /content/dronedataset/No_Fire/resized_frame26960.jpg
# /content/output/train/No_Fire/resized_frame26960.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3210.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3210.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1762.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1762.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2053.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2053.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9214.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9214.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1896.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1896.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1981.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1981.jpg
# /content/dronedataset/No_Fire/resized_frame11683.jpg
# /content/output/train/No_Fire/resized_frame11683.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9474.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9474.jpg
# /content/dronedataset/No_Fire/resized_frame11861.jpg
# /content/output/train/No_Fire/resized_frame11861.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame859.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame859.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7382.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7382.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame717.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame717.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3664.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3664.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10058.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10058.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4265.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4265.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1107.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1107.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1835.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1835.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1889.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1889.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame975.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame975.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2173.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2173.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1957.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1957.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5913.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5913.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5300.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5300.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11553.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11553.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8458.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8458.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2062.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2062.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9478.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9478.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9091.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9091.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2990.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2990.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10392.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10392.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6892.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6892.jpg
# /content/dronedataset/No_Fire/resized_frame11906.jpg
# /content/output/train/No_Fire/resized_frame11906.jpg
# /content/dronedataset/No_Fire/resized_frame16975.jpg
# /content/output/train/No_Fire/resized_frame16975.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2618.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2618.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1225.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1225.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9261.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9261.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9147.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9147.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1927.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1927.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2900.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2900.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10515.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10515.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2959.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2959.jpg
# /content/dronedataset/No_Fire/resized_frame17348.jpg
# /content/output/train/No_Fire/resized_frame17348.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7966.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7966.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame930.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame930.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2507.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2507.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1580.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1580.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5958.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5958.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7755.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7755.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6885.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6885.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2872.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2872.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8680.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8680.jpg
# /content/dronedataset/No_Fire/resized_frame17072.jpg
# /content/output/train/No_Fire/resized_frame17072.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3183.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3183.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1924.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1924.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame175.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame175.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1468.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1468.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5034.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5034.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11001.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11001.jpg
# /content/dronedataset/No_Fire/resized_frame18741.jpg
# /content/output/train/No_Fire/resized_frame18741.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1926.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1926.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8477.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8477.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1826.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1826.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11657.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11657.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8385.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8385.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2025.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2025.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8861.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8861.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11316.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11316.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame480.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame480.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9547.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9547.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10891.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10891.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2706.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2706.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame740.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame740.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2527.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2527.jpg
# /content/dronedataset/No_Fire/resized_frame3608.jpg
# /content/output/train/No_Fire/resized_frame3608.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2115.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2115.jpg
# /content/dronedataset/No_Fire/resized_frame17295.jpg
# /content/output/train/No_Fire/resized_frame17295.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5914.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5914.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4707.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4707.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame773.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame773.jpg
# /content/dronedataset/No_Fire/resized_frame18284.jpg
# /content/output/train/No_Fire/resized_frame18284.jpg
# /content/dronedataset/No_Fire/resized_frame3544.jpg
# /content/output/train/No_Fire/resized_frame3544.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4198.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4198.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3081.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3081.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2205.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2205.jpg
# /content/dronedataset/No_Fire/resized_frame17046.jpg
# /content/output/train/No_Fire/resized_frame17046.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4282.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4282.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3840.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3840.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8346.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8346.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2730.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2730.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7884.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7884.jpg
# /content/dronedataset/No_Fire/resized_frame16822.jpg
# /content/output/train/No_Fire/resized_frame16822.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7225.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7225.jpg
# /content/dronedataset/No_Fire/resized_frame13455.jpg
# /content/output/train/No_Fire/resized_frame13455.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8688.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8688.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9422.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9422.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2444.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2444.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2363.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2363.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10603.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10603.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6992.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6992.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6658.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6658.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame92.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame92.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3105.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3105.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9329.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9329.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1491.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1491.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame77.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame77.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11507.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11507.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1150.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1150.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1176.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1176.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame773.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame773.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10257.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10257.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1842.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1842.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10114.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10114.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6177.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6177.jpg
# /content/dronedataset/No_Fire/resized_frame18709.jpg
# /content/output/train/No_Fire/resized_frame18709.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10089.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10089.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2230.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2230.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5619.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5619.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1494.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1494.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1479.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1479.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9701.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9701.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2227.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2227.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1526.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1526.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5437.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5437.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame40.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame40.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3131.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3131.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2853.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2853.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1629.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1629.jpg
# /content/dronedataset/No_Fire/resized_frame13471.jpg
# /content/output/train/No_Fire/resized_frame13471.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8140.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8140.jpg
# /content/dronedataset/No_Fire/resized_frame11834.jpg
# /content/output/train/No_Fire/resized_frame11834.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10198.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10198.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame762.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame762.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2003.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2003.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1711.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1711.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1129.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1129.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3983.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3983.jpg
# /content/dronedataset/No_Fire/resized_frame18715.jpg
# /content/output/train/No_Fire/resized_frame18715.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10555.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10555.jpg
# /content/dronedataset/No_Fire/resized_frame17335.jpg
# /content/output/train/No_Fire/resized_frame17335.jpg
# /content/dronedataset/No_Fire/resized_frame17221.jpg
# /content/output/train/No_Fire/resized_frame17221.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3100.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3100.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9979.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9979.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2201.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2201.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6033.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6033.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame314.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame314.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11625.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11625.jpg
# /content/dronedataset/No_Fire/resized_frame19989.jpg
# /content/output/train/No_Fire/resized_frame19989.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7857.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7857.jpg
# /content/dronedataset/No_Fire/resized_frame11920.jpg
# /content/output/train/No_Fire/resized_frame11920.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2278.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2278.jpg
# /content/dronedataset/No_Fire/resized_frame16593.jpg
# /content/output/train/No_Fire/resized_frame16593.jpg
# /content/dronedataset/No_Fire/resized_frame26996.jpg
# /content/output/train/No_Fire/resized_frame26996.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1184.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1184.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame694.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame694.jpg
# /content/dronedataset/No_Fire/resized_frame17088.jpg
# /content/output/train/No_Fire/resized_frame17088.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3700.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3700.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1779.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1779.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2456.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2456.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame785.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame785.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame555.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame555.jpg
# /content/dronedataset/No_Fire/resized_frame11880.jpg
# /content/output/train/No_Fire/resized_frame11880.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3299.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3299.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6643.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6643.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame984.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame984.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11152.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11152.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2655.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2655.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2626.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2626.jpg
# /content/dronedataset/No_Fire/resized_frame19077.jpg
# /content/output/train/No_Fire/resized_frame19077.jpg
# /content/dronedataset/No_Fire/resized_frame17297.jpg
# /content/output/train/No_Fire/resized_frame17297.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11518.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11518.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3151.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3151.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8125.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8125.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11308.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11308.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8721.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8721.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2375.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2375.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1056.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1056.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame89.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame89.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame563.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame563.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1048.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1048.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3015.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3015.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame857.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame857.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9455.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9455.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5043.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5043.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame356.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame356.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10819.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10819.jpg
# /content/dronedataset/No_Fire/resized_frame6723.jpg
# /content/output/train/No_Fire/resized_frame6723.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1621.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1621.jpg
# /content/dronedataset/No_Fire/resized_frame16641.jpg
# /content/output/train/No_Fire/resized_frame16641.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2448.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2448.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2464.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2464.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3063.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3063.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11775.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11775.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10146.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10146.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7841.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7841.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10217.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10217.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9779.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9779.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame271.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame271.jpg
# /content/dronedataset/No_Fire/resized_frame17321.jpg
# /content/output/train/No_Fire/resized_frame17321.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11383.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11383.jpg
# /content/dronedataset/No_Fire/resized_frame13440.jpg
# /content/output/train/No_Fire/resized_frame13440.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame551.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame551.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4568.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4568.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2678.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2678.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4038.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4038.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11504.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11504.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame520.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame520.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10376.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10376.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5484.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5484.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7445.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7445.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1447.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1447.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6650.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6650.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame771.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame771.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4297.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4297.jpg
# /content/dronedataset/No_Fire/resized_frame3460.jpg
# /content/output/train/No_Fire/resized_frame3460.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4326.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4326.jpg
# /content/dronedataset/No_Fire/resized_frame6790.jpg
# /content/output/train/No_Fire/resized_frame6790.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11522.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11522.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5001.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5001.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1233.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1233.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame213.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame213.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3107.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3107.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8716.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8716.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3465.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3465.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6508.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6508.jpg
# /content/dronedataset/No_Fire/resized_frame11799.jpg
# /content/output/train/No_Fire/resized_frame11799.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2639.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2639.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9294.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9294.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame108.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame108.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame591.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame591.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame491.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame491.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6230.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6230.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9014.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9014.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2454.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2454.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8437.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8437.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7181.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7181.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1151.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1151.jpg
# /content/dronedataset/No_Fire/resized_frame16653.jpg
# /content/output/train/No_Fire/resized_frame16653.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8322.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8322.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8503.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8503.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1376.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1376.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7503.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7503.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5864.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5864.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1898.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1898.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8316.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8316.jpg
# ...
# /content/output/train/No_Fire/lake_resized_lake_frame700.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6364.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6364.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10608.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10608.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1722.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1722.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3166.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3166.jpg
# /content/dronedataset/No_Fire/resized_frame11723.jpg
# /content/output/train/No_Fire/resized_frame11723.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6780.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6780.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2402.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2402.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1618.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1618.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8604.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8604.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10351.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10351.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5019.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5019.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5780.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5780.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1595.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1595.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame414.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame414.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame387.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame387.jpg
# /content/dronedataset/No_Fire/resized_frame3452.jpg
# /content/output/train/No_Fire/resized_frame3452.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2066.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2066.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame676.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame676.jpg
# /content/dronedataset/No_Fire/resized_frame4359.jpg
# /content/output/train/No_Fire/resized_frame4359.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3077.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3077.jpg
# /content/dronedataset/No_Fire/resized_frame3785.jpg
# /content/output/train/No_Fire/resized_frame3785.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2061.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2061.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1420.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1420.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7361.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7361.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8860.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8860.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4101.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4101.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1297.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1297.jpg
# /content/dronedataset/No_Fire/resized_frame3259.jpg
# /content/output/train/No_Fire/resized_frame3259.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame32.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame32.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8096.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8096.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10877.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10877.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11626.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11626.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2018.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2018.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2648.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2648.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame222.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame222.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1639.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1639.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9719.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9719.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3016.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3016.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7977.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7977.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1829.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1829.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9805.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9805.jpg
# /content/dronedataset/No_Fire/resized_frame16958.jpg
# /content/output/train/No_Fire/resized_frame16958.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2147.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2147.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5727.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5727.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5721.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5721.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2787.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2787.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame855.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame855.jpg
# /content/dronedataset/No_Fire/resized_frame26962.jpg
# /content/output/train/No_Fire/resized_frame26962.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9963.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9963.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3129.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3129.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6414.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6414.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2576.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2576.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3822.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3822.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1496.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1496.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2065.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2065.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1183.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1183.jpg
# /content/dronedataset/No_Fire/resized_frame18791.jpg
# /content/output/train/No_Fire/resized_frame18791.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6341.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6341.jpg
# /content/dronedataset/No_Fire/resized_frame18331.jpg
# /content/output/train/No_Fire/resized_frame18331.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5374.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5374.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1653.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1653.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2129.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2129.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11233.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11233.jpg
# /content/dronedataset/No_Fire/resized_frame3346.jpg
# /content/output/train/No_Fire/resized_frame3346.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8354.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8354.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1157.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1157.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3210.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3210.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame742.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame742.jpg
# /content/dronedataset/No_Fire/resized_frame3299.jpg
# /content/output/train/No_Fire/resized_frame3299.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9088.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9088.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame558.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame558.jpg
# /content/dronedataset/No_Fire/resized_frame16645.jpg
# /content/output/train/No_Fire/resized_frame16645.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3030.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3030.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1424.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1424.jpg
# /content/dronedataset/No_Fire/resized_frame18698.jpg
# /content/output/train/No_Fire/resized_frame18698.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7170.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7170.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8027.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8027.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5089.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5089.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3389.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3389.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2475.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2475.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame123.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame123.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9630.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9630.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8869.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8869.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9233.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9233.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10277.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10277.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1691.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1691.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3001.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3001.jpg
# /content/dronedataset/No_Fire/resized_frame11848.jpg
# /content/output/train/No_Fire/resized_frame11848.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3062.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3062.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3905.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3905.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10435.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10435.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6308.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6308.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11159.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11159.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame465.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame465.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame599.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame599.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6717.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6717.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10013.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10013.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11085.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11085.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8114.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8114.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame609.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame609.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7900.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7900.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10678.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10678.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1092.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1092.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11547.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11547.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame88.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame88.jpg
# /content/dronedataset/No_Fire/resized_frame3773.jpg
# /content/output/train/No_Fire/resized_frame3773.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1649.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1649.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2986.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2986.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5475.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5475.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2484.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2484.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9333.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9333.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3436.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3436.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9369.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9369.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6385.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6385.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1676.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1676.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2665.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2665.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3989.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3989.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4385.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4385.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3851.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3851.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4019.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4019.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9815.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9815.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3263.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3263.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1504.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1504.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8043.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8043.jpg
# /content/dronedataset/No_Fire/resized_frame11790.jpg
# /content/output/train/No_Fire/resized_frame11790.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11489.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11489.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame934.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame934.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2901.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2901.jpg
# /content/dronedataset/No_Fire/resized_frame4290.jpg
# /content/output/train/No_Fire/resized_frame4290.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3124.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3124.jpg

# %%
# Define the path to the subfolder containing the images
test_fire_path = '/content/output/test/Fire'
test_nofire_path = '/content/output/test/No_Fire'
train_fire_path = '/content/output/train/Fire'
train_nofire_path = '/content/output/train/No_Fire'

# Count the number of images in the subfolder
num_images1 = len([name for name in os.listdir(test_fire_path) if os.path.isfile(os.path.join(test_fire_path, name))])
num_images2 = len([name for name in os.listdir(test_nofire_path) if os.path.isfile(os.path.join(test_nofire_path, name))])
num_images3 = len([name for name in os.listdir(train_fire_path) if os.path.isfile(os.path.join(train_fire_path, name))])
num_images4 = len([name for name in os.listdir(train_nofire_path) if os.path.isfile(os.path.join(train_nofire_path, name))])

# Print the number of images in the subfolder
print(f"Number of images in the test/fire: {num_images1}")
print(f"Number of images in the test/nofire: {num_images2}")
print(f"Number of images in the train/fire: {num_images3}")
print(f"Number of images in the train/nofire: {num_images4}")
# Out:
# Number of images in the test/fire: 9047
# Number of images in the test/nofire: 5352
# Number of images in the train/fire: 21108
# Number of images in the train/nofire: 12485

# %% [markdown]
# After that, create a `tf.keras.preprocessing.image.ImageDataGenerator` object which will handle the image dataset for training and testing.
#
# Then the object function called `flow_from_directory` is used provide batch of image dataset according to specification based on function input argument.
#
# 20% from the training data will be taken out and used as validation data

# %%
# data_dir = '/content/dronedataset'
# train_dataset = tf.keras.utils.image_dataset_from_directory(
#   data_dir,
#   validation_split=0.2,
#   subset="training",
#   seed=123,
#   shuffle=True,
#   image_size=(img_height, img_width),
#   batch_size=batch_size)


# validation_dataset = tf.keras.utils.image_dataset_from_directory(
#   data_dir,
#   validation_split=0.2,
#   subset="validation",
#   seed=123,
#   shuffle=True,
#   image_size=(img_height, img_width),
#   batch_size=batch_size)


# Create an instance of the ImageDataGenerator with for training and testing
train_data_generator = ImageDataGenerator( validation_split=0.2) # 20% from training will be leaved out for validation
test_data_generator = ImageDataGenerator()

names = ["Fire" , "No_Fire"] #make sure the spelling is similar to the folder name

# Create the train batch generator
train_batches = train_data_generator.flow_from_directory(
    '/content/output/train',
    target_size = (img_width,img_height),
    class_mode = 'sparse', #make label as integer value
    subset='training',
    batch_size = batch_size,
    shuffle = True,
    color_mode = "rgb",
    classes = names
)

# Create the validation batch generator
validation_batches = train_data_generator.flow_from_directory(
    '/content/output/train',
    target_size = (img_width,img_height),
    class_mode = 'sparse', #make label as integer value
    subset='validation',
    batch_size = batch_size,
    shuffle = True,
    color_mode = "rgb",
    classes = names
)


# Create the test generator
test_batches = test_data_generator.flow_from_directory(
    '/content/output/test',
    target_size = (224,224),
    class_mode = 'sparse', #make label as integer value
    batch_size = batch_size,
    shuffle = True,
    color_mode = "rgb",
    classes = names
)
# Out:
# Found 26875 images belonging to 2 classes.
# Found 6718 images belonging to 2 classes.
# Found 14399 images belonging to 2 classes.

# %% [markdown]
# ### Visualize the data
#
# Here are the first nine images from the training dataset:

# %%
import matplotlib.pyplot as plt

single_train_image_batch = next(train_batches)  #single_train_batch[0] -> image  single_train_batch [1] -> label
batch_images = single_train_image_batch[0]
batch_labels = single_train_image_batch[1]
print(batch_images.shape)
print(batch_labels.shape)

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(batch_images[i].astype("uint8"))
  plt.title(names[batch_labels[i].astype("int")])
  plt.axis("off")
# Out:
# (50, 224, 224, 3)
# (50,)

# %% [markdown]
# ###Create the base model from the pre-trained VGG16
#
# ![Fig-A1-The-standard-VGG-16-network-architecture-as-proposed-in-32-Note-that-only.png](data:image/png;base64,...)
#
# First, instantiate a VGG16 model pre-loaded with weights trained on ImageNet.

# %%
# Create the base model from the pre-trained model VGG16
base_model = tf.keras.applications.VGG16()

# print(type(base_model))
print("****VGG16 original network arhitecture****")
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# ****VGG16 original network arhitecture****
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 4096)           │   102,764,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 1000)           │     4,097,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 138,357,544 (527.79 MB)
#  Trainable params: 138,357,544 (527.79 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.utils.plot_model(base_model, to_file = 'VGG16_basemodel.png', show_shapes = True, show_layer_names=True, dpi=60)

# %% [markdown]
# Create new model, copy all layers in VGG16 but remove the classification block

# %%
base_model = tf.keras.applications.VGG16(weights='imagenet',
        include_top=False)


print("****model after removing copy all VGG16 layers and remove the classification head****")
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ****model after removing copy all VGG16 layers and remove the last layer****
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, None, None, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, None, None, 64) │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, None, None, 64) │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, None, None, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, None, None,     │        73,856 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, None, None,     │       147,584 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, None, None,     │       295,168 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, None, None,     │     1,180,160 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Add  new classification block/head with Global Average Polling + Dense + Drop Out + Dense (final Dense with 2 outputs)

# %%
#Freezing the existing weights
base_model.trainable = False


# Create a new Sequential Model
model = Sequential()

# --- Add the Base Model as the first "Layer" ---
# Think of this as adding the entire pre-trained brain at the bottom (except the head)
model.add(base_model)

# --- Add the Classification Head using .add() ---------

# Step A: The Universal Connector
model.add(GlobalAveragePooling2D())

# Step B: Hidden Layer
model.add(Dense(128, activation='relu'))

# Step C: Dropout
model.add(Dropout(0.5))

# Step D: Final Output
model.add(Dense(2))
#---------------------------------------------------------

print("****model after add new dense layer replacing the previous VGG16 last layer****")
model.summary()
# Out:
# ****model after add new dense layer replacing the previous VGG16 last layer****
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, None, None,     │    14,714,688 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,780,610 (56.38 MB)
#  Trainable params: 65,922 (257.51 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# ###Compile the model
#
# Compile the model before training it. Since there are two classes, use the tf.keras.losses.BinaryCrossentropy loss with from_logits=True since the model provides a linear output.

# %%
learning_rate = 0.001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ###Train the model

# %%
history = model.fit(train_batches,
                    epochs=10,
                    validation_data=validation_batches)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/nn.py:717: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 223s 375ms/step - accuracy: 0.9242 - loss: 0.2777 - val_accuracy: 0.9495 - val_loss: 0.2119
# Epoch 2/10
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 180s 335ms/step - accuracy: 0.9816 - loss: 0.0485 - val_accuracy: 0.9080 - val_loss: 0.3558
# Epoch 3/10
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 180s 335ms/step - accuracy: 0.9875 - loss: 0.0345 - val_accuracy: 0.9543 - val_loss: 0.1918
# Epoch 4/10
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 181s 336ms/step - accuracy: 0.9891 - loss: 0.0293 - val_accuracy: 0.9513 - val_loss: 0.2340
# Epoch 5/10
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 181s 336ms/step - accuracy: 0.9900 - loss: 0.0272 - val_accuracy: 0.9552 - val_loss: 0.2839
# Epoch 6/10
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 181s 336ms/step - accuracy: 0.9922 - loss: 0.0213 - val_accuracy: 0.9463 - val_loss: 0.2231
# Epoch 7/10
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 181s 336ms/step - accuracy: 0.9923 - loss: 0.0194 - val_accuracy: 0.9481 - val_loss: 0.3313
# Epoch 8/10
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 181s 336ms/step - accuracy: 0.9943 - loss: 0.0170 - val_accuracy: 0.9501 - val_loss: 0.2631
# Epoch 9/10
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 181s 336ms/step - accuracy: 0.9936 - loss: 0.0191 - val_accuracy: 0.9405 - val_loss: 0.2651
# Epoch 10/10
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 181s 337ms/step - accuracy: 0.9946 - loss: 0.0142 - val_accuracy: 0.9458 - val_loss: 0.4356

# %% [markdown]
# ### Plot the learning curves

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### Test the model

# %%
# print(test_batches.shape)
test_loss, test_acc = model.evaluate(test_batches)

print('Test accuracy:', test_acc)
# Out:
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 97s 335ms/step - accuracy: 0.9862 - loss: 0.0791
# Test accuracy: 0.9852767586708069

# %% [markdown]
# Test the developed model in several test images and visual the image, the predicted label, actual label and the probability (in %)

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i].astype("uint8"), img[i].astype("uint8")
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(img)
  predicted_label = np.argmax(predictions_array[i])

  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("Predicted label: {}  Actual label: {}   Prob:{:2.0f}%".format(names[predicted_label],
                                names[true_label],
                                100*np.max(predictions_array)),
                                color=color)


single_test_image_batch = next(test_batches)
predicted_label_prob = model(single_test_image_batch[0]) # single_test_image_batch[0] -> batches of images; single_test_image_batch[1] -> batches of label
predicted_label_prob = tf.nn.softmax(predicted_label_prob)


plt.figure(figsize=(15, 15))
for index in range(9):
  ax = plt.subplot(3, 3, index + 1)
  plot_image(index,predicted_label_prob,single_test_image_batch[1],single_test_image_batch[0])
  plt.title("Testing image index: {}".format(index))

# %% [markdown]
# ## (Section 2) Train your model with image/data augmentation
#
# When you don't have a large image dataset, it's a good practice to artificially introduce sample diversity by applying random, yet realistic, transformations to the training images, such as rotation and horizontal flipping. This helps expose the model to different aspects of the training data and reduce overfitting. You can learn more about data augmentation in this tutorial.
#
# In this case, an instance of `ImageDataGenerator` can be created to include with augmentation mechanism

# %%
# Create an instance of the ImageDataGenerator with desired augmentation options for training and validation
train_data_generator = ImageDataGenerator( validation_split=0.2,
                                          rotation_range = 20,
                                          width_shift_range=0.2,
                                          height_shift_range=0.2,
                                          )

# %%
# Create the train batch generator
train_batches = train_data_generator.flow_from_directory(
    '/content/output/train',
    target_size = (img_width,img_height),
    class_mode = 'sparse', #make label as integer value
    subset='training',
    batch_size = batch_size,
    shuffle = True,
    color_mode = "rgb",
    classes = names
)
# Out:
# Found 26875 images belonging to 2 classes.

# %%
import matplotlib.pyplot as plt

single_train_image_batch = next(train_batches)  #single_train_batch[0] -> image  single_train_batch [1] -> label
batch_images = single_train_image_batch[0]
batch_labels = single_train_image_batch[1]
print(batch_images.shape)
print(batch_labels.shape)

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(batch_images[i].astype("uint8"))
  plt.title(names[batch_labels[i].astype("int")])
  plt.axis("off")
# Out:
# (50, 224, 224, 3)
# (50,)

# %% [markdown]
# ##(Section 3) Partialy Fine Tuning

# %%
# 1. Load Base Model

base_model = tf.keras.applications.VGG16(weights='imagenet',
        include_top=False)


# 2. Reset: Freeze EVERYTHING first
base_model.trainable = False
base_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_12 (InputLayer)     │ (None, None, None, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, None, None, 64) │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, None, None, 64) │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, None, None, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, None, None,     │        73,856 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, None, None,     │       147,584 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, None, None,     │       295,168 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, None, None,     │     1,180,160 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
# 3. Build the Sequential Model
model = Sequential()
model.add(base_model)

# 4. Add Classification Head
model.add(GlobalAveragePooling2D())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2))
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, None, None,     │    14,714,688 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,780,610 (56.38 MB)
#  Trainable params: 2,425,730 (9.25 MB)
#  Non-trainable params: 12,354,880 (47.13 MB)

# %% [markdown]
# ### Compile the model

# %%
learning_rate = 0.00001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Train the model

# %%
history = model.fit(train_batches,
                    epochs=3,
                    validation_data=validation_batches)
# Out:
# Epoch 1/3
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 410s 758ms/step - accuracy: 0.8884 - loss: 2.7550 - val_accuracy: 0.9555 - val_loss: 0.2259
# Epoch 2/3
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 401s 745ms/step - accuracy: 0.9571 - loss: 0.1133 - val_accuracy: 0.8817 - val_loss: 0.4260
# Epoch 3/3
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 396s 736ms/step - accuracy: 0.9607 - loss: 0.1011 - val_accuracy: 0.9564 - val_loss: 0.3300
