# %% [markdown]
# <a href="https://colab.research.google.com/github/amir-asari/SEBB4083-AI--202220232/blob/main/SEBB4083_VGG16_transferlearning2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## (Section 1)Transfer learning using VGG16 pretrained model
#
# There are 2 approaches in performing transfer learning
#
# 1. Feature extraction:  Use the representations learned by a previous network to extract meaningful features from new samples. You simply add a new classifier, which will be trained from scratch, on top of the pretrained model so that you can repurpose the feature maps learned previously for the dataset.
#
# 2. Fine-tuning: Unfreeze a few of the top layers of a frozen model base and jointly train both the newly-added classifier layers and the last layers of the base model. This allows us to "fine-tune" the higher-order feature representations in the base model in order to make them more relevant for the specific task.

# %% [markdown]
# ### Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil

import tensorflow as tf
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.model_selection import train_test_split

# !pip install zipfile
from zipfile import ZipFile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement zipfile (from versions: none)
# ERROR: No matching distribution found for zipfile

# %% [markdown]
# ###Data preprocessing
#
#
#
# ####Download data from gdrive link

# %%
! gdown --id 1YSRzwDWQJAyy2-7fX8qH4jzQef-QJFQG
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1YSRzwDWQJAyy2-7fX8qH4jzQef-QJFQG
# To: /content/dronedataset.zip
# 100% 1.57G/1.57G [00:21<00:00, 74.1MB/s]

# %% [markdown]
# ####Unzip the download file

# %%
with ZipFile('/content/dronedataset.zip','r') as zipObj:
  zipObj.extractall()

# %% [markdown]
# ####Load data using Keras utility
#
# Next, load these images off disk using the helpful tf.keras.utils.image_dataset_from_directory utility. This will take you from a directory of images on disk to a tf.data.Dataset in just a couple lines of code.

# %% [markdown]
# Create a dataset
#
# Define some parameters for the ImageDataGenerator:

# %%
batch_size = 50 # Of course here, we are using mini-batch gradient descent 
img_height = 224
img_width = 224

# %% [markdown]
# Data splitting, into 70% training data and 30% testing data. Once splitted, all data will saved in folder called training_data and testing_data

# %%
# Define the path to your dataset directory
dataset_dir = '/content/dronedataset'

# Define the path to the directory where you want to create the train and test folders
output_dir = '/content/output'

# Define the percentage of data to be used for testing
test_split = 0.3

# Get the list of subfolders in the dataset directory
subfolders = [subfolder for subfolder in os.listdir(dataset_dir) if os.path.isdir(os.path.join(dataset_dir, subfolder))]

print(subfolders)

# Define the train and test folder paths
train_dir = os.path.join(output_dir, 'train')
test_dir = os.path.join(output_dir, 'test')

# Delete train and test folders if they already exist
if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
if os.path.exists(test_dir):
    shutil.rmtree(test_dir)

# Create the train and test folders in the output directory
os.makedirs(train_dir)
os.makedirs(test_dir)

# Iterate over each subfolder and split the images into train and test sets
for subfolder in subfolders:
    subfolder_path = os.path.join(dataset_dir, subfolder)
    images = os.listdir(subfolder_path)
    train_images, test_images = train_test_split(images, test_size=test_split, random_state=42)

    # Create the subfolders inside train and test directories
    train_subfolder_dir = os.path.join(train_dir, subfolder)
    test_subfolder_dir = os.path.join(test_dir, subfolder)
    os.makedirs(train_subfolder_dir)
    os.makedirs(test_subfolder_dir)
    
    # Move the train images to the train folder
    for image in train_images:
        src = os.path.join(subfolder_path, image)
        dst = os.path.join(train_dir, subfolder, image)
        print(src)
        print(dst)
        shutil.copyfile(src, dst)
    
    # Move the test images to the test folder
    for image in test_images:
        src = os.path.join(subfolder_path, image)
        dst = os.path.join(test_dir, subfolder, image)
        shutil.copyfile(src, dst)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/dronedataset/No_Fire/lake_resized_lake_frame8700.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8700.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4036.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4036.jpg
# /content/dronedataset/No_Fire/resized_frame17208.jpg
# /content/output/train/No_Fire/resized_frame17208.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3532.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3532.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1345.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1345.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1342.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1342.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5748.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5748.jpg
# /content/dronedataset/No_Fire/resized_frame3538.jpg
# /content/output/train/No_Fire/resized_frame3538.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1664.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1664.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2761.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2761.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame652.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame652.jpg
# /content/dronedataset/No_Fire/resized_frame16687.jpg
# /content/output/train/No_Fire/resized_frame16687.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2692.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2692.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2885.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2885.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1865.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1865.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2834.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2834.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6322.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6322.jpg
# /content/dronedataset/No_Fire/resized_frame16812.jpg
# /content/output/train/No_Fire/resized_frame16812.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2177.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2177.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9749.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9749.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame493.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame493.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8697.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8697.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5972.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5972.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10894.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10894.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame763.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame763.jpg
# /content/dronedataset/No_Fire/resized_frame18773.jpg
# /content/output/train/No_Fire/resized_frame18773.jpg
# /content/dronedataset/No_Fire/resized_frame18690.jpg
# /content/output/train/No_Fire/resized_frame18690.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2896.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2896.jpg
# /content/dronedataset/No_Fire/resized_frame16807.jpg
# /content/output/train/No_Fire/resized_frame16807.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7348.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7348.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame621.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame621.jpg
# /content/dronedataset/No_Fire/resized_frame11934.jpg
# /content/output/train/No_Fire/resized_frame11934.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7849.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7849.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3715.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3715.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2525.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2525.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2129.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2129.jpg
# /content/dronedataset/No_Fire/resized_frame17288.jpg
# /content/output/train/No_Fire/resized_frame17288.jpg
# /content/dronedataset/No_Fire/resized_frame16602.jpg
# /content/output/train/No_Fire/resized_frame16602.jpg
# /content/dronedataset/No_Fire/resized_frame3351.jpg
# /content/output/train/No_Fire/resized_frame3351.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11225.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11225.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame262.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame262.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame51.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame51.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2290.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2290.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6248.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6248.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8292.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8292.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9267.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9267.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame320.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame320.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2768.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2768.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1941.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1941.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8651.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8651.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11252.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11252.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4401.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4401.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame987.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame987.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4310.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4310.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4149.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4149.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5137.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5137.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame984.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame984.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1383.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1383.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3880.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3880.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10226.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10226.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame565.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame565.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2445.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2445.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3452.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3452.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4041.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4041.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame364.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame364.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3721.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3721.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1188.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1188.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6076.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6076.jpg
# /content/dronedataset/No_Fire/resized_frame3603.jpg
# /content/output/train/No_Fire/resized_frame3603.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11397.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11397.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5311.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5311.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4190.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4190.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8648.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8648.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame866.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame866.jpg
# /content/dronedataset/No_Fire/resized_frame16770.jpg
# /content/output/train/No_Fire/resized_frame16770.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7686.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame
jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8665.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8665.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3929.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3929.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1916.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1916.jpg
# /content/dronedataset/No_Fire/resized_frame16852.jpg
# /content/output/train/No_Fire/resized_frame16852.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame868.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame868.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6760.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6760.jpg
# /content/dronedataset/No_Fire/resized_frame3347.jpg
# /content/output/train/No_Fire/resized_frame3347.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1984.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1984.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1601.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1601.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11267.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11267.jpg
# /content/dronedataset/No_Fire/resized_frame3630.jpg
# /content/output/train/No_Fire/resized_frame3630.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3250.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3250.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1404.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1404.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7628.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7628.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8296.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8296.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame598.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame598.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9194.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9194.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9765.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9765.jpg
# /content/dronedataset/No_Fire/resized_frame3392.jpg
# /content/output/train/No_Fire/resized_frame3392.jpg
# /content/dronedataset/No_Fire/resized_frame3772.jpg
# /content/output/train/No_Fire/resized_frame3772.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame353.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame353.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1600.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1600.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1591.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1591.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9823.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9823.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame869.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame869.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame100.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame100.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame568.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame568.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9550.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9550.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3324.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3324.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4629.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4629.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11334.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11334.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10665.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10665.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7097.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7097.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3256.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3256.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1011.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1011.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1869.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1869.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7479.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7479.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame6882.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame6882.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1420.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1420.jpg
# /content/dronedataset/No_Fire/resized_frame18308.jpg
# /content/output/train/No_Fire/resized_frame18308.jpg
# /content/dronedataset/No_Fire/resized_frame3229.jpg
# /content/output/train/No_Fire/resized_frame3229.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5100.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5100.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7708.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7708.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2914.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2914.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1417.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1417.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame4950.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame4950.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame991.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame991.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9204.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9204.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2852.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2852.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11605.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11605.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame8393.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame8393.jpg
# /content/dronedataset/No_Fire/resized_frame16734.jpg
# /content/output/train/No_Fire/resized_frame16734.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame3064.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame3064.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame233.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame233.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1059.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1059.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10373.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10373.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5155.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5155.jpg
# /content/dronedataset/No_Fire/resized_frame3483.jpg
# /content/output/train/No_Fire/resized_frame3483.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7934.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7934.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10515.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10515.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10432.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10432.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7328.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7328.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2759.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2759.jpg
# /content/dronedataset/No_Fire/resized_frame11944.jpg
# /content/output/train/No_Fire/resized_frame11944.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame9151.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame9151.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame10178.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame10178.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame11266.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame11266.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame3644.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame3644.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame2448.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame2448.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1104.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1104.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame7621.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame7621.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame1573.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame1573.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame5004.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame5004.jpg
# /content/dronedataset/No_Fire/resized_test_nofire_frame1841.jpg
# /content/output/train/No_Fire/resized_test_nofire_frame1841.jpg
# /content/dronedataset/No_Fire/lake_resized_lake_frame2996.jpg
# /content/output/train/No_Fire/lake_resized_lake_frame2996.jpg

# %%
# Define the path to the subfolder containing the images
test_fire_path = '/content/output/test/Fire'
test_nofire_path = '/content/output/test/No_Fire'
train_fire_path = '/content/output/train/Fire'
train_nofire_path = '/content/output/train/No_Fire'

# Count the number of images in the subfolder
num_images1 = len([name for name in os.listdir(test_fire_path) if os.path.isfile(os.path.join(test_fire_path, name))])
num_images2 = len([name for name in os.listdir(test_nofire_path) if os.path.isfile(os.path.join(test_nofire_path, name))])
num_images3 = len([name for name in os.listdir(train_fire_path) if os.path.isfile(os.path.join(train_fire_path, name))])
num_images4 = len([name for name in os.listdir(train_nofire_path) if os.path.isfile(os.path.join(train_nofire_path, name))])

# Print the number of images in the subfolder
print(f"Number of images in the test/fire: {num_images1}")
print(f"Number of images in the test/nofire: {num_images2}")
print(f"Number of images in the train/fire: {num_images3}")
print(f"Number of images in the train/nofire: {num_images4}")
# Out:
# Number of images in the test/fire: 9047
# Number of images in the test/nofire: 5352
# Number of images in the train/fire: 21108
# Number of images in the train/nofire: 12485

# %% [markdown]
# After that, create a `tf.keras.preprocessing.image.ImageDataGenerator` object which will handle the image dataset for training and testing.
#
# Then the object function called `flow_from_directory` is used provide batch of image dataset according to specification based on function input argument.
#
# 20% from the training data will be taken out and used as validation data

# %%
# data_dir = '/content/dronedataset'
# train_dataset = tf.keras.utils.image_dataset_from_directory(
#   data_dir,
#   validation_split=0.2,
#   subset="training",
#   seed=123,
#   shuffle=True,
#   image_size=(img_height, img_width),
#   batch_size=batch_size)


# validation_dataset = tf.keras.utils.image_dataset_from_directory(
#   data_dir,
#   validation_split=0.2,
#   subset="validation",
#   seed=123,
#   shuffle=True,
#   image_size=(img_height, img_width),
#   batch_size=batch_size)


# Create an instance of the ImageDataGenerator with for training and testing
train_data_generator = ImageDataGenerator( validation_split=0.2) # 20% from training will be leaved out for validation
test_data_generator = ImageDataGenerator()

names = ["Fire" , "No_Fire"] #make sure the spelling is similar to the folder name

# Create the train batch generator
train_batches = train_data_generator.flow_from_directory(
    '/content/output/train',
    target_size = (img_width,img_height),
    class_mode = 'sparse', #make label as integer value
    subset='training',
    batch_size = batch_size,
    shuffle = True,
    color_mode = "rgb",
    classes = names
)

# Create the validation batch generator
validation_batches = train_data_generator.flow_from_directory(
    '/content/output/train',
    target_size = (img_width,img_height),
    class_mode = 'sparse', #make label as integer value
    subset='validation',
    batch_size = batch_size,
    shuffle = True,
    color_mode = "rgb",
    classes = names
)


# Create the test generator
test_batches = test_data_generator.flow_from_directory(
    '/content/output/test',
    target_size = (224,224),
    class_mode = 'sparse', #make label as integer value
    batch_size = batch_size,
    shuffle = True,
    color_mode = "rgb",
    classes = names
)
# Out:
# Found 26875 images belonging to 2 classes.
# Found 6718 images belonging to 2 classes.
# Found 14399 images belonging to 2 classes.

# %% [markdown]
# ### Visualize the data
#
# Here are the first nine images from the training dataset:

# %%
import matplotlib.pyplot as plt

single_train_image_batch = train_batches.next()  #single_train_batch[0] -> image  single_train_batch [1] -> label
batch_images = single_train_image_batch[0]
batch_labels = single_train_image_batch[1]
print(batch_images.shape)
print(batch_labels.shape)

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(batch_images[i].astype("uint8"))
  plt.title(names[batch_labels[i].astype("int")])
  plt.axis("off")
# Out:
# (50, 224, 224, 3)
# (50,)

# %% [markdown]
# ###Create the base model from the pre-trained VGG16
#
# ![Fig-A1-The-standard-VGG-16-network-architecture-as-proposed-in-32-Note-that-only.png](data:image/png;base64,...)
#
# First, instantiate a VGG16 model pre-loaded with weights trained on ImageNet.

# %%
# Create the base model from the pre-trained model VGG16
base_model = tf.keras.applications.VGG16()

# print(type(base_model))
print("****VGG16 original network arhitecture****")
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 3s 0us/step
# ****VGG16 original network arhitecture****
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(base_model, to_file = 'VGG16_basemodel.png', show_shapes = True)

# %% [markdown]
# Create new model, copy all layers in VGG16 from the 1st until 2nd last layer

# %%
#Create our model by copying from the 1st layer to the 2nd last layer

model = tf.keras.models.Sequential()
for layer in base_model.layers[0:-1]:
  model.add(layer)

print("****model after removing copy all VGG16 layers and remove the last layer****")
model.summary()
# Out:
# ****model after removing copy all VGG16 layers and remove the last layer****
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
# =================================================================
# Total params: 134,260,544
# Trainable params: 134,260,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Add the last layer with new dense layer with 2 outputs replacing the dense layer with 1000 outputs

# %%
#Freezing the existing weights
for layer in model.layers:
    layer.trainable = False
print(model.summary())

#add new layer which will replace the previous VGG16 last layer
model.add(tf.keras.layers.Dense(2))

print("****model after add new dense layer replacing the previous VGG16 last layer****")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
# =================================================================
# Total params: 134,260,544
# Trainable params: 0
# Non-trainable params: 134,260,544
# _________________________________________________________________
# None
# ****model after add new dense layer replacing the previous VGG16 last layer****
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  dense (Dense)               (None, 2)                 8194
#
# =================================================================
# Total params: 134,268,738
# Trainable params: 8,194
# Non-trainable params: 134,260,544
# _________________________________________________________________

# %% [markdown]
# ###Compile the model
#
# Compile the model before training it. Since there are two classes, use the tf.keras.losses.BinaryCrossentropy loss with from_logits=True since the model provides a linear output.

# %%
learning_rate = 0.001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ###Train the model

# %%
history = model.fit(train_batches,
                    epochs=3,
                    validation_data=validation_batches)
# Out:
# Epoch 1/3
# 538/538 [==============================] - 170s 315ms/step - loss: 0.0360 - accuracy: 0.9875 - val_loss: 0.2345 - val_accuracy: 0.9393
# Epoch 2/3
# 538/538 [==============================] - 159s 295ms/step - loss: 0.0236 - accuracy: 0.9924 - val_loss: 0.2048 - val_accuracy: 0.9521
# Epoch 3/3
# 538/538 [==============================] - 159s 295ms/step - loss: 0.0174 - accuracy: 0.9945 - val_loss: 0.1347 - val_accuracy: 0.9603

# %% [markdown]
# ### Plot the learning curves
#
# Let's take a look at the learning curves of the training and validation accuracy/loss when using the MobileNetV2 base model as a fixed feature extractor.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### Test the model

# %%
# print(test_batches.shape)
test_loss, test_acc = model.evaluate(test_batches)

print('Test accuracy:', test_acc)
# Out:
# 288/288 [==============================] - 70s 241ms/step - loss: 0.0445 - accuracy: 0.9858
# Test accuracy: 0.985762894153595

# %% [markdown]
# Test the developed model in several test images and visual the image, the predicted label, actual label and the probability (in %)

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i].astype("uint8"), img[i].astype("uint8")
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(img)
  predicted_label = np.argmax(predictions_array[i])
  
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("Predicted label: {}  Actual label: {}   Prob:{:2.0f}%".format(names[predicted_label],
                                names[true_label],
                                100*np.max(predictions_array)),
                                color=color)


single_test_image_batch = test_batches.next()
predicted_label_prob = model(single_test_image_batch[0]) # single_test_image_batch[0] -> batches of images; single_test_image_batch[1] -> batches of label
predicted_label_prob = tf.nn.softmax(predicted_label_prob)


plt.figure(figsize=(15, 15))
for index in range(9):
  ax = plt.subplot(3, 3, index + 1)
  plot_image(index,predicted_label_prob,single_test_image_batch[1],single_test_image_batch[0])
  plt.title("Testing image index: {}".format(index))

# %% [markdown]
# ## (Section 2) Train your model with image/data augmentation
#
# When you don't have a large image dataset, it's a good practice to artificially introduce sample diversity by applying random, yet realistic, transformations to the training images, such as rotation and horizontal flipping. This helps expose the model to different aspects of the training data and reduce overfitting. You can learn more about data augmentation in this tutorial.
#
# In this case, an instance of `ImageDataGenerator` can be created to include with augmentation mechanism

# %%
# Create an instance of the ImageDataGenerator with desired augmentation options for training and validation
train_data_generator = ImageDataGenerator( validation_split=0.2,
                                          rotation_range = 20,
                                          width_shift_range=0.2,
                                          height_shift_range=0.2,
                                          )

# %%
# Create the train batch generator
train_batches = train_data_generator.flow_from_directory(
    '/content/output/train',
    target_size = (img_width,img_height),
    class_mode = 'sparse', #make label as integer value
    subset='training',
    batch_size = batch_size,
    shuffle = True,
    color_mode = "rgb",
    classes = names
)
# Out:
# Found 26875 images belonging to 2 classes.

# %%
# import matplotlib.pyplot as plt

# single_train_image_batch = train_batches.next()  #single_train_batch[0] -> image  single_train_batch [1] -> label
# batch_images = single_train_image_batch[0]
# batch_labels = single_train_image_batch[1]
# print(batch_images.shape)
# print(batch_labels.shape)

# plt.figure(figsize=(10, 10))
# for i in range(9):
#   ax = plt.subplot(3, 3, i + 1)
#   plt.imshow(batch_images[i].astype("uint8"))
#   plt.title(names[batch_labels[i].astype("int")])
#   plt.axis("off")

# %% [markdown]
# ### Recreate the model from VGG16

# %%
#Create our model by copying from the 1st layer to the 2nd last layer

model = tf.keras.models.Sequential()
for layer in base_model.layers[0:-1]:
  model.add(layer)

# %% [markdown]
# ### Freezen some layers and add last laser with dense layer (2 outputs)

# %%
#Freezing the existing weights
for layer in model.layers:
    layer.trainable = False

#add new layer which will replace the previous VGG16 last layer
model.add(tf.keras.layers.Dense(2))

# %% [markdown]
# ### Compile the model

# %%
learning_rate = 0.001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Train the model

# %%
history = model.fit(train_batches,
                    epochs=3,
                    validation_data=validation_batches)
# Out:
# Epoch 1/3
# 538/538 [==============================] - 399s 738ms/step - loss: 0.2034 - accuracy: 0.9214 - val_loss: 0.1205 - val_accuracy: 0.9559
# Epoch 2/3
# 529/538 [============================>.] - ETA: 6s - loss: 0.1441 - accuracy: 0.9452
